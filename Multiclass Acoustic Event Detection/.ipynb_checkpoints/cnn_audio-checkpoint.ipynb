# %%
# !pip uninstall tensorflow
import numpy 
import os
import glob
import pandas as pd
import librosa
import tensorflow as tf
from sklearn.metrics import confusion_matrix
import seaborn as sns
from keras.preprocessing import image
from tensorflow.keras.models import load_model

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = '-1
'

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 15884597729578891647
# xla_global_id: -1
# ]

# %%
# from keras import backend as K
# K.tensorflow_backend._get_available_gpus()
from tensorflow.python.client import device_lib
physical_devices = tf.config.list_physical_devices('GPU')
physical_devices
# Out:
# []

# %%
path = os.getcwd()
path=os.path.join(path, "Documents", "courses", "MLSP", "Audio_Classification-MLSP", "Audio_Classification-MLSP")
data_path=os.path.join(path, "train")
label_path=path
data=pd.read_csv(os.path.join(label_path, "annotations.csv"))
# npy_files = glob.glob(os.path.join(data_path, "*.npy"))

# %%
inputs=[]
i=0
files=data["fname"]
for file in files:
    arr=numpy.load(os.path.join(data_path, file))
    m,n,o=arr.shape
    arr.resize(n,o)
#     print(arr.shape)
    mel_spect = librosa.power_to_db(arr, ref=numpy.max)
    inputs.append(mel_spect)
    i=i+1

# %%
print(inputs[999])
arr
# Out:
# [[-26.330238 -21.989447 -20.607533 ... -26.798738 -25.923897 -26.986965]
#  [-28.490978 -21.584297 -19.280537 ... -23.238422 -23.046486 -23.830498]
#  [-23.714306 -22.412607 -18.014997 ... -20.873995 -21.258144 -22.754637]
#  ...
#  [-20.146936 -18.803898 -18.330667 ... -18.313105 -18.329493 -17.85233 ]
#  [-19.35617  -18.47731  -18.13743  ... -18.030918 -18.13076  -17.434338]
#  [-18.95461  -18.420706 -18.589504 ... -18.172123 -18.222296 -17.32702 ]]
# array([[0.0779112 , 0.21167965, 0.2909849 , ..., 0.0699439 , 0.08555277,
#         0.06697725],
#        [0.04737247, 0.23237747, 0.39497554, ..., 0.1587748 , 0.1659492 ,
#         0.13853967],
#        [0.14229614, 0.19202733, 0.5285962 , ..., 0.27366814, 0.25050092,
#         0.17748438],
#        ...,
#        [0.32354158, 0.44079223, 0.491538  , ..., 0.4935298 , 0.49167082,
#         0.5487707 ],
#        [0.38815638, 0.4752178 , 0.51390254, ..., 0.5266619 , 0.5146925 ,
#         0.60421306],
#        [0.4257579 , 0.48145223, 0.4630985 , ..., 0.5098138 , 0.5039579 ,
#         0.6193294 ]], dtype=float32)

# %%
inputs[0].shape
# Out:
# (128, 314)

# %%
# frame["feature"][0].shape

maxs=0
for input in inputs:
    m,n=input.shape
    if maxs<n:
        maxs=n
maxs
features=[]
for a in inputs:
    mat=numpy.pad(a, [(0, 0), (0, maxs-a[0].size)], mode='constant', constant_values=0)
    mat=mat.reshape((mat.shape[0], mat.shape[1], 1))
    features.append(mat)
maxs=0
features=numpy.array(features)
for a in features:
    print(a.shape)
# Out:
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)
# (128, 2584, 1)

# %%
data["label"].describe()
# Out:
# count     1000
# unique      10
# top       Bark
# freq       100
# Name: label, dtype: object

# %%
df_Bark = data[data["label"]=='Bark']

# %%
df_Bark.reset_index(inplace=True)

# %%
i=0
for mat in features:
    features[i]= tf.convert_to_tensor(features[i])
    i=i+1

# %%
X=features
y=data["label"]
y.shape
# Out:
# (1000,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle="true")

print(y_test.shape)
val_label=pd.Series(list(y_test))
val_label.value_counts()
# data={"val":y_test}
# ldf=pd.DataFrame(data, index=["label"])
# ldf["val"].value_counts()
# Out:
# (200,)
# Doorbell                                 27
# Knock                                    23
# Vehicle_horn_and_car_horn_and_honking    22
# Shatter                                  20
# Meow                                     19
# Walk_and_footsteps                       19
# Bark                                     18
# Siren                                    18
# Crying_and_sobbing                       17
# Microwave_oven                           17
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
test_encoder = LabelEncoder()
test_ = test_encoder.fit_transform(y_test)
to_onehot=to_categorical(test_)
y_test=to_onehot
train_encoder = LabelEncoder()
train_ = train_encoder.fit_transform(y_train)
to_onehot=to_categorical(train_)
y_train=to_onehot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24260/1064337163.py in <module>
#       2 from keras.utils import to_categorical
#       3 test_encoder = LabelEncoder()
# ----> 4 test_ = test_encoder.fit_transform(y_test)
#       5 to_onehot=to_categorical(test_)
#       6 y_test=to_onehot
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in fit_transform(self, y)
#     114         y : array-like of shape (n_samples,)
#     115         """
# --> 116         y = column_or_1d(y, warn=True)
#     117         self.classes_, y = _unique(y, return_inverse=True)
#     118         return y
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in column_or_1d(y, warn)
#     919         return np.ravel(y)
#     920
# --> 921     raise ValueError(
#     922         "y should be a 1d array, "
#     923         "got an array of shape {} instead.".format(shape))
#
# ValueError: y should be a 1d array, got an array of shape (200, 10) instead.

# %%
type(y_test)
# dict={'features':features, 'labels':data["label"]}
# frame=pd.DataFrame(dict)
# frame["labels"].value_counts()
# frame = frame.to_numpy().astype(numpy.float32)
# X=frame["features"]
# y=frame["labels"]

# %%
y_test

# %%
# !pip install keras
# import tensorflow as tf
# from tf.keras.layers.normalization import BatchNormalization
# from tf.keras.layers.normalization import BatchNormalization
model = tf.keras.models.Sequential([
    #first_convolution
    tf.keras.layers.Conv2D(16, (3,3), activation='linear', input_shape=(128, 2584, 1)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu')
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Dropout(0.25),
    #second_convolution
    tf.keras.layers.Conv2D(32, (3,3), activation='linear'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu')
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    #third_convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='linear', kernel_regularizer =tf.keras.regularizers.l1( l=0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu')
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    #fourth_convolution
    tf.keras.layers.Conv2D(64, (3,3), activation='linear', kernel_regularizer =tf.keras.regularizers.l1( l=0.01)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu')
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Dropout(0.25),
    #Fully connected 1st layer
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer =tf.keras.regularizers.l1( l=0.01)),
    tf.keras.layers.Dense(10, activation='softmax') 
]) 
# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=input_shape))
# model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
# model.add(MaxPooling2D(pool_size=(2, 2)))
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(num_classes, activation='softmax'))

# %%
len(X_train)
model.summary()

# %%
from keras import backend as K
from sklearn.metrics import precision_score , recall_score
def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %%
# X_train = numpy.asarray(X_train).astype(numpy.array)
# y_train = numpy.asarray(y_train).astype(numpy.array)
from matplotlib import pyplot as plt
model.compile(loss='categorical_crossentropy', optimizer='adam', run_eagerly=True, metrics=['accuracy', f1_m, precision_m, recall_m])
`
# Out:
# Epoch 1/35
# 13/13 [==============================] - 832s 61s/step - loss: 12.0078 - accuracy: 0.2062 - f1_m: 0.2027 - precision_m: 0.2241 - recall_m: 0.1863 - val_loss: 3.0911 - val_accuracy: 0.1200 - val_f1_m: 0.0328 - val_precision_m: 0.1039 - val_recall_m: 0.0195
# Epoch 2/35
# 13/13 [==============================] - 3598s 295s/step - loss: 2.5997 - accuracy: 0.4100 - f1_m: 0.3532 - precision_m: 0.5212 - recall_m: 0.2692 - val_loss: 4.0687 - val_accuracy: 0.1600 - val_f1_m: 0.0917 - val_precision_m: 0.1499 - val_recall_m: 0.0664
# Epoch 3/35
# 13/13 [==============================] - 434s 32s/step - loss: 1.6702 - accuracy: 0.4600 - f1_m: 0.4436 - precision_m: 0.7102 - recall_m: 0.3245 - val_loss: 6.3330 - val_accuracy: 0.1250 - val_f1_m: 0.0912 - val_precision_m: 0.1183 - val_recall_m: 0.0742
# Epoch 4/35
# 13/13 [==============================] - 444s 34s/step - loss: 1.3294 - accuracy: 0.5675 - f1_m: 0.5478 - precision_m: 0.8118 - recall_m: 0.4159 - val_loss: 8.2236 - val_accuracy: 0.1550 - val_f1_m: 0.1102 - val_precision_m: 0.1264 - val_recall_m: 0.0977
# Epoch 5/35
# 13/13 [==============================] - 391s 30s/step - loss: 1.0542 - accuracy: 0.6438 - f1_m: 0.6149 - precision_m: 0.8377 - recall_m: 0.4880 - val_loss: 10.4417 - val_accuracy: 0.1850 - val_f1_m: 0.1411 - val_precision_m: 0.1460 - val_recall_m: 0.1367
# Epoch 6/35
# 13/13 [==============================] - 427s 33s/step - loss: 0.9246 - accuracy: 0.6875 - f1_m: 0.6743 - precision_m: 0.8587 - recall_m: 0.5565 - val_loss: 12.5457 - val_accuracy: 0.1750 - val_f1_m: 0.1390 - val_precision_m: 0.1414 - val_recall_m: 0.1367
# Epoch 7/35
# 13/13 [==============================] - 451s 34s/step - loss: 0.8231 - accuracy: 0.7250 - f1_m: 0.7220 - precision_m: 0.8834 - recall_m: 0.6118 - val_loss: 13.7481 - val_accuracy: 0.1750 - val_f1_m: 0.1395 - val_precision_m: 0.1424 - val_recall_m: 0.1367
# Epoch 8/35
# 13/13 [==============================] - 398s 30s/step - loss: 0.6990 - accuracy: 0.7462 - f1_m: 0.7239 - precision_m: 0.8741 - recall_m: 0.6190 - val_loss: 14.9530 - val_accuracy: 0.1700 - val_f1_m: 0.1344 - val_precision_m: 0.1359 - val_recall_m: 0.1328
# Epoch 9/35
# 13/13 [==============================] - 416s 32s/step - loss: 0.5871 - accuracy: 0.8025 - f1_m: 0.8006 - precision_m: 0.8990 - recall_m: 0.7224 - val_loss: 14.4374 - val_accuracy: 0.1750 - val_f1_m: 0.1392 - val_precision_m: 0.1419 - val_recall_m: 0.1367
# Epoch 10/35
# 13/13 [==============================] - 411s 32s/step - loss: 0.6142 - accuracy: 0.7962 - f1_m: 0.7855 - precision_m: 0.8870 - recall_m: 0.7055 - val_loss: 14.5317 - val_accuracy: 0.1450 - val_f1_m: 0.1114 - val_precision_m: 0.1134 - val_recall_m: 0.1094
# Epoch 31/35
# 13/13 [==============================] - 513s 40s/step - loss: 0.1234 - accuracy: 0.9663 - f1_m: 0.9618 - precision_m: 0.9707 - recall_m: 0.9531 - val_loss: 2.2181 - val_accuracy: 0.5100 - val_f1_m: 0.5218 - val_precision_m: 0.5605 - val_recall_m: 0.4883
# Epoch 32/35
# 13/13 [==============================] - 448s 35s/step - loss: 0.1184 - accuracy: 0.9737 - f1_m: 0.9708 - precision_m: 0.9792 - recall_m: 0.9627 - val_loss: 3.4236 - val_accuracy: 0.4700 - val_f1_m: 0.4513 - val_precision_m: 0.4780 - val_recall_m: 0.4297
# Epoch 33/35
# 13/13 [==============================] - 519s 40s/step - loss: 0.1661 - accuracy: 0.9638 - f1_m: 0.9620 - precision_m: 0.9649 - recall_m: 0.9591 - val_loss: 2.9906 - val_accuracy: 0.4850 - val_f1_m: 0.4343 - val_precision_m: 0.4581 - val_recall_m: 0.4141
# Epoch 34/35
# 13/13 [==============================] - 451s 34s/step - loss: 0.2217 - accuracy: 0.9475 - f1_m: 0.9505 - precision_m: 0.9551 - recall_m: 0.9459 - val_loss: 4.0807 - val_accuracy: 0.4350 - val_f1_m: 0.3898 - val_precision_m: 0.4121 - val_recall_m: 0.3711
# Epoch 35/35
# 13/13 [==============================] - 2459s 202s/step - loss: 0.1420 - accuracy: 0.9563 - f1_m: 0.9576 - precision_m: 0.9647 - recall_m: 0.9507 - val_loss: 3.1578 - val_accuracy: 0.4800 - val_f1_m: 0.5125 - val_precision_m: 0.5613 - val_recall_m: 0.4727

# %%
history=model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=64, epochs=35, verbose = 1)
# Out:
# Epoch 1/35
# 13/13 [==============================] - 833s 63s/step - loss: 0.1255 - accuracy: 0.9550 - f1_m: 0.9533 - precision_m: 0.9597 - recall_m: 0.9471 - val_loss: 3.7138 - val_accuracy: 0.4450 - val_f1_m: 0.4665 - val_precision_m: 0.4812 - val_recall_m: 0.4531
# Epoch 2/35
# 13/13 [==============================] - 396s 30s/step - loss: 0.1664 - accuracy: 0.9588 - f1_m: 0.9578 - precision_m: 0.9601 - recall_m: 0.9555 - val_loss: 2.8098 - val_accuracy: 0.5050 - val_f1_m: 0.4928 - val_precision_m: 0.5196 - val_recall_m: 0.4688
# Epoch 3/35
# 13/13 [==============================] - 453s 35s/step - loss: 0.0968 - accuracy: 0.9750 - f1_m: 0.9734 - precision_m: 0.9782 - recall_m: 0.9688 - val_loss: 3.2396 - val_accuracy: 0.4750 - val_f1_m: 0.4833 - val_precision_m: 0.5089 - val_recall_m: 0.4609
# Epoch 4/35
# 13/13 [==============================] - 446s 34s/step - loss: 0.0940 - accuracy: 0.9663 - f1_m: 0.9692 - precision_m: 0.9734 - recall_m: 0.9651 - val_loss: 3.0956 - val_accuracy: 0.5150 - val_f1_m: 0.5097 - val_precision_m: 0.5430 - val_recall_m: 0.4805
# Epoch 5/35
# 13/13 [==============================] - 424s 32s/step - loss: 0.1330 - accuracy: 0.9650 - f1_m: 0.9667 - precision_m: 0.9732 - recall_m: 0.9603 - val_loss: 2.5963 - val_accuracy: 0.5800 - val_f1_m: 0.5877 - val_precision_m: 0.5982 - val_recall_m: 0.5781
# Epoch 6/35
# 13/13 [==============================] - 420s 32s/step - loss: 0.1219 - accuracy: 0.9725 - f1_m: 0.9691 - precision_m: 0.9744 - recall_m: 0.9639 - val_loss: 2.9129 - val_accuracy: 0.5400 - val_f1_m: 0.5358 - val_precision_m: 0.5446 - val_recall_m: 0.5273
# Epoch 7/35
# 13/13 [==============================] - 383s 29s/step - loss: 0.1641 - accuracy: 0.9513 - f1_m: 0.9525 - precision_m: 0.9543 - recall_m: 0.9507 - val_loss: 2.5135 - val_accuracy: 0.5900 - val_f1_m: 0.5807 - val_precision_m: 0.6007 - val_recall_m: 0.5625
# Epoch 8/35
# 13/13 [==============================] - 402s 31s/step - loss: 0.1802 - accuracy: 0.9500 - f1_m: 0.9510 - precision_m: 0.9574 - recall_m: 0.9447 - val_loss: 2.7726 - val_accuracy: 0.5500 - val_f1_m: 0.5125 - val_precision_m: 0.5173 - val_recall_m: 0.5078
# Epoch 9/35
# 13/13 [==============================] - 401s 30s/step - loss: 0.1125 - accuracy: 0.9600 - f1_m: 0.9601 - precision_m: 0.9647 - recall_m: 0.9555 - val_loss: 2.7784 - val_accuracy: 0.5750 - val_f1_m: 0.5629 - val_precision_m: 0.5803 - val_recall_m: 0.5469
# Epoch 10/35
# 13/13 [==============================] - 380s 29s/step - loss: 0.0555 - accuracy: 0.9837 - f1_m: 0.9837 - precision_m: 0.9855 - recall_m: 0.9820 - val_loss: 3.1313 - val_accuracy: 0.5600 - val_f1_m: 0.5516 - val_precision_m: 0.5650 - val_recall_m: 0.5391
# Epoch 11/35
# 13/13 [==============================] - 356s 27s/step - loss: 0.0485 - accuracy: 0.9837 - f1_m: 0.9837 - precision_m: 0.9867 - recall_m: 0.9808 - val_loss: 3.0170 - val_accuracy: 0.5750 - val_f1_m: 0.5878 - val_precision_m: 0.5937 - val_recall_m: 0.5820
# Epoch 12/35
# 13/13 [==============================] - 334s 26s/step - loss: 0.0357 - accuracy: 0.9875 - f1_m: 0.9885 - precision_m: 0.9903 - recall_m: 0.9868 - val_loss: 2.7354 - val_accuracy: 0.6250 - val_f1_m: 0.5920 - val_precision_m: 0.6024 - val_recall_m: 0.5820
# Epoch 13/35
# 13/13 [==============================] - 339s 26s/step - loss: 0.1119 - accuracy: 0.9787 - f1_m: 0.9771 - precision_m: 0.9795 - recall_m: 0.9748 - val_loss: 2.4764 - val_accuracy: 0.6400 - val_f1_m: 0.6175 - val_precision_m: 0.6348 - val_recall_m: 0.6016
# Epoch 14/35
# 13/13 [==============================] - 407s 32s/step - loss: 0.0786 - accuracy: 0.9762 - f1_m: 0.9771 - precision_m: 0.9783 - recall_m: 0.9760 - val_loss: 2.5767 - val_accuracy: 0.6450 - val_f1_m: 0.6104 - val_precision_m: 0.6198 - val_recall_m: 0.6016
# Epoch 15/35
# 13/13 [==============================] - 340s 26s/step - loss: 0.0990 - accuracy: 0.9775 - f1_m: 0.9765 - precision_m: 0.9783 - recall_m: 0.9748 - val_loss: 2.2395 - val_accuracy: 0.6600 - val_f1_m: 0.5976 - val_precision_m: 0.6016 - val_recall_m: 0.5938
# Epoch 16/35
# 13/13 [==============================] - 348s 27s/step - loss: 0.0571 - accuracy: 0.9875 - f1_m: 0.9868 - precision_m: 0.9868 - recall_m: 0.9868 - val_loss: 1.9623 - val_accuracy: 0.7250 - val_f1_m: 0.7009 - val_precision_m: 0.7067 - val_recall_m: 0.6953
# Epoch 17/35
# 13/13 [==============================] - 320s 24s/step - loss: 0.1207 - accuracy: 0.9737 - f1_m: 0.9747 - precision_m: 0.9759 - recall_m: 0.9736 - val_loss: 2.1715 - val_accuracy: 0.7200 - val_f1_m: 0.6999 - val_precision_m: 0.7087 - val_recall_m: 0.6914
# Epoch 18/35
# 13/13 [==============================] - 310s 24s/step - loss: 0.1076 - accuracy: 0.9712 - f1_m: 0.9723 - precision_m: 0.9747 - recall_m: 0.9700 - val_loss: 2.2537 - val_accuracy: 0.6900 - val_f1_m: 0.6610 - val_precision_m: 0.6791 - val_recall_m: 0.6445
# Epoch 19/35
# 13/13 [==============================] - 308s 24s/step - loss: 0.0435 - accuracy: 0.9850 - f1_m: 0.9861 - precision_m: 0.9879 - recall_m: 0.9844 - val_loss: 2.3779 - val_accuracy: 0.7100 - val_f1_m: 0.6614 - val_precision_m: 0.6668 - val_recall_m: 0.6562
# Epoch 20/35
# 13/13 [==============================] - 313s 24s/step - loss: 0.0539 - accuracy: 0.9812 - f1_m: 0.9820 - precision_m: 0.9832 - recall_m: 0.9808 - val_loss: 3.1474 - val_accuracy: 0.6350 - val_f1_m: 0.6211 - val_precision_m: 0.6383 - val_recall_m: 0.6055
# Epoch 21/35
# 13/13 [==============================] - 349s 27s/step - loss: 0.0388 - accuracy: 0.9862 - f1_m: 0.9867 - precision_m: 0.9903 - recall_m: 0.9832 - val_loss: 2.3985 - val_accuracy: 0.7050 - val_f1_m: 0.6730 - val_precision_m: 0.6912 - val_recall_m: 0.6562
# Epoch 22/35
# 13/13 [==============================] - 352s 27s/step - loss: 0.0341 - accuracy: 0.9850 - f1_m: 0.9868 - precision_m: 0.9892 - recall_m: 0.9844 - val_loss: 2.1509 - val_accuracy: 0.7350 - val_f1_m: 0.7071 - val_precision_m: 0.7155 - val_recall_m: 0.6992
# Epoch 23/35
# 13/13 [==============================] - 349s 27s/step - loss: 0.0362 - accuracy: 0.9887 - f1_m: 0.9830 - precision_m: 0.9841 - recall_m: 0.9820 - val_loss: 5.1712 - val_accuracy: 0.5550 - val_f1_m: 0.5726 - val_precision_m: 0.5749 - val_recall_m: 0.5703
# Epoch 24/35
# 13/13 [==============================] - 335s 26s/step - loss: 0.0900 - accuracy: 0.9800 - f1_m: 0.9808 - precision_m: 0.9808 - recall_m: 0.9808 - val_loss: 4.1415 - val_accuracy: 0.6650 - val_f1_m: 0.6424 - val_precision_m: 0.6573 - val_recall_m: 0.6289
# Epoch 25/35
# 13/13 [==============================] - 332s 26s/step - loss: 0.0427 - accuracy: 0.9900 - f1_m: 0.9904 - precision_m: 0.9916 - recall_m: 0.9892 - val_loss: 7.3313 - val_accuracy: 0.5050 - val_f1_m: 0.5059 - val_precision_m: 0.5079 - val_recall_m: 0.5039
# Epoch 26/35
# 13/13 [==============================] - 343s 26s/step - loss: 0.0513 - accuracy: 0.9887 - f1_m: 0.9880 - precision_m: 0.9891 - recall_m: 0.9868 - val_loss: 3.8078 - val_accuracy: 0.6400 - val_f1_m: 0.6079 - val_precision_m: 0.6144 - val_recall_m: 0.6016
# Epoch 27/35
# 13/13 [==============================] - 330s 25s/step - loss: 0.0600 - accuracy: 0.9850 - f1_m: 0.9856 - precision_m: 0.9856 - recall_m: 0.9856 - val_loss: 3.1457 - val_accuracy: 0.6450 - val_f1_m: 0.6226 - val_precision_m: 0.6372 - val_recall_m: 0.6094
# Epoch 28/35
# 13/13 [==============================] - 325s 25s/step - loss: 0.0752 - accuracy: 0.9775 - f1_m: 0.9759 - precision_m: 0.9795 - recall_m: 0.9724 - val_loss: 2.6755 - val_accuracy: 0.6500 - val_f1_m: 0.6144 - val_precision_m: 0.6238 - val_recall_m: 0.6055
# Epoch 29/35
# 13/13 [==============================] - 327s 25s/step - loss: 0.0299 - accuracy: 0.9887 - f1_m: 0.9885 - precision_m: 0.9891 - recall_m: 0.9880 - val_loss: 2.8944 - val_accuracy: 0.6700 - val_f1_m: 0.6563 - val_precision_m: 0.6603 - val_recall_m: 0.6523
# Epoch 30/35
# 13/13 [==============================] - 356s 27s/step - loss: 0.0333 - accuracy: 0.9862 - f1_m: 0.9831 - precision_m: 0.9843 - recall_m: 0.9820 - val_loss: 2.9038 - val_accuracy: 0.6850 - val_f1_m: 0.6706 - val_precision_m: 0.6734 - val_recall_m: 0.6680
# Epoch 31/35
# 13/13 [==============================] - 346s 26s/step - loss: 0.0296 - accuracy: 0.9837 - f1_m: 0.9850 - precision_m: 0.9856 - recall_m: 0.9844 - val_loss: 2.9595 - val_accuracy: 0.6600 - val_f1_m: 0.6523 - val_precision_m: 0.6562 - val_recall_m: 0.6484
# Epoch 32/35
# 13/13 [==============================] - 336s 26s/step - loss: 0.0281 - accuracy: 0.9912 - f1_m: 0.9904 - precision_m: 0.9904 - recall_m: 0.9904 - val_loss: 3.1182 - val_accuracy: 0.6550 - val_f1_m: 0.6549 - val_precision_m: 0.6615 - val_recall_m: 0.6484
# Epoch 33/35
# 13/13 [==============================] - 335s 26s/step - loss: 0.0154 - accuracy: 0.9962 - f1_m: 0.9952 - precision_m: 0.9952 - recall_m: 0.9952 - val_loss: 2.9084 - val_accuracy: 0.6950 - val_f1_m: 0.6839 - val_precision_m: 0.6882 - val_recall_m: 0.6797
# Epoch 34/35
# 13/13 [==============================] - 342s 26s/step - loss: 0.0265 - accuracy: 0.9912 - f1_m: 0.9916 - precision_m: 0.9928 - recall_m: 0.9904 - val_loss: 2.7925 - val_accuracy: 0.7000 - val_f1_m: 0.6812 - val_precision_m: 0.6867 - val_recall_m: 0.6758
# Epoch 35/35
# 13/13 [==============================] - 345s 26s/step - loss: 0.0217 - accuracy: 0.9912 - f1_m: 0.9916 - precision_m: 0.9928 - recall_m: 0.9904 - val_loss: 2.5936 - val_accuracy: 0.6900 - val_f1_m: 0.6733 - val_precision_m: 0.6747 - val_recall_m: 0.6719

# %%
history=model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=64, epochs=20, verbose = 1)
# Out:
# Epoch 1/20
# 13/13 [==============================] - 395s 30s/step - loss: 0.0197 - accuracy: 0.9925 - f1_m: 0.9934 - precision_m: 0.9940 - recall_m: 0.9928 - val_loss: 2.7280 - val_accuracy: 0.7050 - val_f1_m: 0.6862 - val_precision_m: 0.6931 - val_recall_m: 0.6797
# Epoch 2/20
# 10/13 [======================>.......] - ETA: 1:15 - loss: 0.0242 - accuracy: 0.9922 - f1_m: 0.9914 - precision_m: 0.9922 - recall_m: 0.9906

# %%
model.save('C:\Users\dell\Documents\Courses\MLSP\Audio_Classification-MLSP\Audio_Classification-MLSP\70_accu')
# model.test_on_batch(X_test, y_test)

# %%
model.metrics_names
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4720/205546209.py in <module>
#       1 model.metrics_names
# ----> 2 plt.plot(history.history['accuracy'])
#       3 plt.plot(history.history['val_accuracy'])
#       4 plt.title('model accuracy')
#       5 plt.ylabel('accuracy')
#
# NameError: name 'history' is not defined

# %%
path_save=os.path.join(path, "Documents", "courses", "MLSP", "models")
model.save(path_save)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\dell\Documents\courses\MLSP\Audio_Classification-MLSP\Audio_Classification-MLSP\Documents\courses\MLSP\models\assets
# INFO:tensorflow:Assets written to: C:\Users\dell\Documents\courses\MLSP\Audio_Classification-MLSP\Audio_Classification-MLSP\Documents\courses\MLSP\models\assets

# %%
accuracy = model.evaluate(X_test, y_test)
print('n', 'Test_Accuracy:-', accuracy[1])
pred = model.predict(X_test, y_test)
y_pred = np.argmax(pred, axis=1)
y_true = np.argmax(pred, axis=1)
print('confusion matrix')
print(confusion_matrix(y_true, y_pred))
    #confusion matrix
f, ax = plt.subplots(figsize=(8,5))
sns.heatmap(confusion_matrix(y_true, y_pred), annot=True, fmt=".0f", ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
# Out:
# 7/7 [==============================] - 6s 812ms/step - loss: 6.6156 - accuracy: 0.5750 - f1_score: 0.1652 - precision_m: 1.0000 - recall_m: 0.0902
# n Test_Accuracy:- 0.574999988079071
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11296/3112765177.py in <module>
#       1 accuracy = model.evaluate(X_test, y_test)
#       2 print('n', 'Test_Accuracy:-', accuracy[1])
# ----> 3 pred = model.predict(X_test, y_test)
#       4 y_pred = np.argmax(pred, axis=1)
#       5 y_true = np.argmax(pred, axis=1)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\data_adapter.py in __init__(self, x, y, sample_weights, sample_weight_modes, batch_size, epochs, steps, shuffle, **kwargs)
#     264         # If batch_size is not passed but steps is, calculate from the input
#     265         # data.  Default to 32 for backwards compat.
# --> 266         if not batch_size:
#     267             batch_size = int(math.ceil(num_samples / steps)) if steps else 32
#     268
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# a=[[1,2,3]]
# b=numpy.pad(a, [(0, 0), (0, 2)], mode='constant', constant_values=0)
# b
# Out:
# array([[1, 2, 3, 0, 0]])

# %%
# d=[128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128, 128
#   ]
# len(d)
# Out:
# 800
